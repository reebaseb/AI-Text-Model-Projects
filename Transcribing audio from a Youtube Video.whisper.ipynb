# %% [markdown]
# <a href="https://colab.research.google.com/github/reebaseb/AI-Text-Model-Projects/blob/main/Transcribing%20audio%20from%20a%20Youtube%20Video.whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 20.3 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade yt-dlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 22.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 104.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 52.0 MB/s eta 0:00:00
# ...

# %%
# !yt-dlp https://youtu.be/2TF3HFMDSF4
# Out:
# [youtube] Extracting URL: https://youtu.be/2TF3HFMDSF4
# [youtube] 2TF3HFMDSF4: Downloading webpage
# [youtube] 2TF3HFMDSF4: Downloading android player API JSON
# [youtube] 2TF3HFMDSF4: Downloading MPD manifest
# [info] 2TF3HFMDSF4: Downloading 1 format(s): 247+251
# [dashsegments] Total fragments: 159
# [download] Destination: We need a new logo – Stable Diffusion [2TF3HFMDSF4].f247.webm
# [download] 100% of   36.72MiB in 00:00:48 at 775.53KiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: We need a new logo – Stable Diffusion [2TF3HFMDSF4].f251.webm
# [download] 100% of    9.81MiB in 00:00:00 at 41.60MiB/s
# [Merger] Merging formats into "We need a new logo – Stable Diffusion [2TF3HFMDSF4].webm"
# Deleting original file We need a new logo – Stable Diffusion [2TF3HFMDSF4].f247.webm (pass -k to keep)
# Deleting original file We need a new logo – Stable Diffusion [2TF3HFMDSF4].f251.webm (pass -k to keep)

# %% [markdown]
# Visit your OpenAI account to get an API Key -> https://platform.openai.com/account/api-keys

# %%
# get the openai secret key
import getpass
import openai

secret_key = getpass.getpass('Please enter your openai key: ')
openai.api_key = secret_key
# Out:
# Please enter your openai key: ··········

# %%
# !pip install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=394a373f1bb2564f284a1e1e3809d332500561d67b474144e41a5108281b771f
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# ...

# %%
# !ffmpeg -i input.webm -vn -ab 128k output.mp3
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
audio_file = open("output.mp3", "rb")
transcript = openai.Audio.transcribe("whisper-1", audio_file, response_format="verbose_json")
print(transcript)
# Out:
# {
#   "task": "transcribe",
#   "language": "english",
#   "duration": 840.43,
#   "segments": [
#     {
#       "id": 0,
#       "seek": 0,
#       "start": 0.0,
#       "end": 5.5600000000000005,
#       "text": " I'm going to walk you through how to create a company logo with Stable Diffusion for free",
#       "tokens": [
#         286,
#         478,
#         516,
#         281,
#         1792,
#         291,
#         807,
#         577,
#         281,
#         1884,
#         257,
#         2237,
#         9699,
#         365,
#         745,
#         712,
#         413,
#         3661,
#         5704,
#         337,
#         1737
#       ],
#       "temperature": 0.0,
#       "avg_logprob": -0.2653586617831526,
#       "compression_ratio": 1.6176470588235294,
#       "no_speech_prob": 0.347765177488327,
#       "transient": false
#     },
#     {
#       "id": 1,
#       "seek": 0,
#       "start": 5.5600000000000005,
#       "end": 8.56,
# ...

# %%
transcript['text']
# Out:
# "I'm going to walk you through how to create a company logo with Stable Diffusion for free in your Google CoLab notebook. So this is the Stable Diffusion Google CoLab. They set this up so you can run this in the Google environment. You don't need to download anything onto your computer. So it's much easier to run and it also gives you a free GPU, which is like a specialized computer that's very good at running this type of thing quickly. So I'm just going to click create a copy to drive and then that's going to create a copy. It's just creating a copy right now. It might take a couple of minutes. Okay a copy is created and we're basically just going to go through this setup process here. Now we have this copy, we can call it whatever I want. It's this is ours now and we can run this. It says it requires higher RAM. Don't worry about that. Okay, I'm just going to get rid of any other sessions. So hopefully this will run now. Disconnect. So that is connecting. Just to make sure that yo
# ...

# %%
for segment in transcript['segments']:
    start_minutes, start_seconds = divmod(segment["start"], 60)
    timestamp = f"{round(start_minutes):02d}:{round(start_seconds):02d}"
    text = segment["text"]

    print(f"{timestamp} - {text}")
# Out:
# 00:00 -  I'm going to walk you through how to create a company logo with Stable Diffusion for free
# 00:06 -  in your Google CoLab notebook.
# 00:09 -  So this is the Stable Diffusion Google CoLab.
# 00:14 -  They set this up so you can run this in the Google environment.
# 00:17 -  You don't need to download anything onto your computer.
# 00:20 -  So it's much easier to run and it also gives you a free GPU, which is like a specialized
# 00:25 -  computer that's very good at running this type of thing quickly.
# 00:29 -  So I'm just going to click create a copy to drive and then that's going to create a copy.
# 00:39 -  It's just creating a copy right now.
# 00:40 -  It might take a couple of minutes.
# 00:50 -  Okay a copy is created and we're basically just going to go through this setup process
# 00:55 -  here.
# 00:56 -  Now we have this copy, we can call it whatever I want.
# 00:59 -  It's this is ours now and we can run this.
# 01:04 -  It says it requires higher RAM.
# ...
